# %%
import pandas as pd
import numpy as np

# %%
import os, sys

project_root = os.path.abspath(os.path.join(os.getcwd(), "../.."))
if project_root not in sys.path:
    sys.path.append(project_root)

# %%
from src.models.quantile_regression import QuantileRegressionV1
from src.optimizers.RMSProp import RMSPropOtimizer

# %%
data = pd.read_csv("../../dataset/foodDeli_processed/train_processed.csv")

# %%
data.head()
# Out:
#    Delivery_person_Age  Delivery_person_Ratings  Distance_km  \
# 0             1.283313                 0.846622    -1.202059
# 1             0.762428                -0.418372     2.263776
# 2            -1.147486                -0.734620    -1.118905
# 3             1.456942                 0.214125    -0.035496
# 4             0.415171                -0.102123    -0.613995
#
#    Preparation_Time  Weather_conditions_Fog  Weather_conditions_Sandstorms  \
# 0          1.228728                       0                              0
# 1         -1.218497                       0                              0
# 2          1.228728                       0                              1
# 3          0.005115                       0                              0
# 4          1.228728                       0                              0
#
#    Weather_conditions_Stormy  Weather_conditions_Sunny  \
# 0                          0                         1
# 1                          1                         0
# 2                          0                         0
# 3                          0                         1
# 4                          0                         0
#
#    Weather_conditions_Windy  Road_traffic_density_Jam  ...  \
# 0                         0                         0  ...
# 1                         0                         1  ...
# 2                         0                         0  ...
# 3                         0                         0  ...
# 4                         0                         0  ...
#
#    Type_of_order_Meal  Type_of_order_Snack  Type_of_vehicle_motorcycle  \
# 0                   0                    1                           1
# 1                   0                    1                           0
# 2                   0                    0                           1
# 3                   0                    0                           1
# 4                   0                    1                           0
#
#    Type_of_vehicle_scooter  Vehicle_condition_1  Vehicle_condition_2  \
# 0                        0                    0                    1
# 1                        1                    0                    1
# 2                        0                    0                    0
# 3                        0                    0                    0
# 4                        1                    1                    0
#
#    Festival_Yes  City_Semi-Urban  City_Urban  Time_taken
# 0             0                0           1          24
# 1             0                0           0          33
# 2             0                0           1          26
# 3             0                0           0          21
# 4             0                0           0          30
#
# [5 rows x 23 columns]

# %%
np.random.seed(42)
shuffled_indices = np.random.permutation(len(data))

train_size = int(len(data) * 0.8)

data_train = data.iloc[shuffled_indices[:train_size]]
data_test = data.iloc[shuffled_indices[train_size:]]

# %%
data_train.shape
# Out:
# (30043, 23)

# %%
data_test.shape
# Out:
# (7511, 23)

# %%
X_train = np.array(data_train.drop(columns="Time_taken"))
y_train = np.array(data_train["Time_taken"])
X_test = np.array(data_test.drop(columns="Time_taken"))
y_test = np.array(data_test["Time_taken"])

# %%
X_train = np.hstack([np.ones((X_train.shape[0], 1)), X_train])
X_test = np.hstack([np.ones((X_test.shape[0], 1)), X_test])

# %%
rmsprop = RMSPropOtimizer(lr=0.05)

# %%
model = QuantileRegressionV1(optimizer=rmsprop)

# %%
model.fit(X_train, y_train, epochs=10000)
# Out:
# Epoch 0/10000, Loss: 23.8476
# Epoch 100/10000, Loss: 3.8909
# Epoch 200/10000, Loss: 1.7942
# Epoch 300/10000, Loss: 1.4485
# Epoch 400/10000, Loss: 1.3434
# Epoch 500/10000, Loss: 1.2619
# Epoch 600/10000, Loss: 1.1939
# Epoch 700/10000, Loss: 1.1433
# Epoch 800/10000, Loss: 1.1109
# Epoch 900/10000, Loss: 1.0957
# Epoch 1000/10000, Loss: 1.0908
# Epoch 1100/10000, Loss: 1.0892
# Epoch 1200/10000, Loss: 1.0889
# Epoch 1300/10000, Loss: 1.0889
# Epoch 8200/10000, Loss: 1.0891
# Epoch 8300/10000, Loss: 1.0890
# Epoch 8400/10000, Loss: 1.0890
# Epoch 8500/10000, Loss: 1.0890
# Epoch 8600/10000, Loss: 1.0891
# Epoch 8700/10000, Loss: 1.0890
# Epoch 8800/10000, Loss: 1.0891
# Epoch 8900/10000, Loss: 1.0891
# Epoch 9000/10000, Loss: 1.0891
# Epoch 9100/10000, Loss: 1.0890
# Epoch 9200/10000, Loss: 1.0890
# Epoch 9300/10000, Loss: 1.0891
# Epoch 9400/10000, Loss: 1.0891
# Epoch 9500/10000, Loss: 1.0890
# Epoch 9600/10000, Loss: 1.0891
# Epoch 9700/10000, Loss: 1.0891
# Epoch 9800/10000, Loss: 1.0890
# Epoch 9900/10000, Loss: 1.0890
# Epoch 9999/10000, Loss: 1.0891

# %%
loss = model.loss

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 5))
plt.plot(loss, label='Pinball Loss', color='#1E88E5', linewidth=2)

plt.title('Training Loss Curve (Quantile Regression)', fontsize=14, fontweight='bold', pad=15)
plt.xlabel('Epochs', fontsize=12, labelpad=10)
plt.ylabel('Loss Value (lr=0.05)', fontsize=12, labelpad=10)

plt.grid(True, linestyle='--', alpha=0.5)
plt.legend(fontsize=11, loc='upper right')

plt.tight_layout()
plt.show()

# %%
y_pred = model.predict(X_test)

test_pinball_loss = model.pinball_loss(y_test, y_pred)
test_mae = np.mean(np.abs(y_test - y_pred))
test_rmse = np.sqrt(np.mean((y_test - y_pred)**2))

coverage_ratio = np.mean(y_test <= y_pred)

print(f"Test Pinball Loss (tau=0.9): {test_pinball_loss:.4f}")
print(f"Test MAE: {test_mae:.4f}")
print(f"Test RMSE: {test_rmse:.4f}")
print(f"Test Coverage Ratio: {coverage_ratio:.4f}")
# Out:
# Test Pinball Loss (tau=0.9): 1.0794
# Test MAE: 8.3895
# Test RMSE: 9.9758
# Test Coverage Ratio: 0.8902

# %%
model.save_weights("../../results/weights/RMSProp/rms_weights.npy")
# Out:
# Saved.

# %%
np.save("../../results/weights/RMSProp/rms_loss_1.npy", np.array(loss))
print("Đã lưu biến loss thành công.")
# Out:
# Đã lưu biến loss thành công.

# %%
# 1. Đọc dữ liệu loss từ các tệp .npy
# (Đường dẫn tương đối tính từ thư mục notebooks/training/)
loss_01 = np.load("../../results/weights/RMSProp/rms_loss_01.npy")
loss_05 = np.load("../../results/weights/RMSProp/rms_loss_05.npy")
loss_1 = np.load("../../results/weights/RMSProp/rms_loss_1.npy")
import matplotlib.pyplot as plt
# 2. Khởi tạo biểu đồ so sánh
plt.figure(figsize=(12, 6))

# Vẽ 3 đường với các màu sắc tương phản rõ nét
plt.plot(loss_01[:4000], label='lr = 0.01', color='#E53935', linewidth=1.8, alpha=0.9)
plt.plot(loss_05[:4000], label='lr = 0.05', color='#FFB300', linewidth=1.8, alpha=0.9)
plt.plot(loss_1[:4000], label='lr = 0.1', color='#1E88E5', linewidth=1.8, alpha=0.9)

# Cấu hình tiêu đề và các trục tọa độ
plt.title('RMSProp Optimizer: Đường cong hàm mất mát', fontsize=14, fontweight='bold', pad=15)
plt.xlabel('Epochs', fontsize=12, labelpad=10)
plt.ylabel('Giá trị hàm loss', fontsize=12, labelpad=10)

# Cấu hình lưới bổ trợ (grid) và ghi chú (legend)
plt.grid(True, linestyle='--', alpha=0.5)
plt.legend(fontsize=11, loc='upper right')

# Tối ưu hóa khoảng cách hiển thị
plt.tight_layout()

# Hiển thị đồ thị
plt.show()
