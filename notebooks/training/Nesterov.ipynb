# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
import os, sys

project_root = os.path.abspath(os.path.join(os.getcwd(), "../.."))
if project_root not in sys.path:
    sys.path.append(project_root)

# %%
from src.models.quantile_regression import QuantileRegressionV1
from src.optimizers.Nesterov import NesterovOptimizer

# %%
data = pd.read_csv("../../dataset/foodDeli_processed/train_processed.csv")

# %%
data.head()
# Out:
#    Delivery_person_Age  Delivery_person_Ratings  Distance_km  \
# 0             1.283313                 0.846622    -1.202059
# 1             0.762428                -0.418372     2.263776
# 2            -1.147486                -0.734620    -1.118905
# 3             1.456942                 0.214125    -0.035496
# 4             0.415171                -0.102123    -0.613995
#
#    Preparation_Time  Weather_conditions_Fog  Weather_conditions_Sandstorms  \
# 0          1.228728                       0                              0
# 1         -1.218497                       0                              0
# 2          1.228728                       0                              1
# 3          0.005115                       0                              0
# 4          1.228728                       0                              0
#
#    Weather_conditions_Stormy  Weather_conditions_Sunny  \
# 0                          0                         1
# 1                          1                         0
# 2                          0                         0
# 3                          0                         1
# 4                          0                         0
#
#    Weather_conditions_Windy  Road_traffic_density_Jam  ...  \
# 0                         0                         0  ...
# 1                         0                         1  ...
# 2                         0                         0  ...
# 3                         0                         0  ...
# 4                         0                         0  ...
#
#    Type_of_order_Meal  Type_of_order_Snack  Type_of_vehicle_motorcycle  \
# 0                   0                    1                           1
# 1                   0                    1                           0
# 2                   0                    0                           1
# 3                   0                    0                           1
# 4                   0                    1                           0
#
#    Type_of_vehicle_scooter  Vehicle_condition_1  Vehicle_condition_2  \
# 0                        0                    0                    1
# 1                        1                    0                    1
# 2                        0                    0                    0
# 3                        0                    0                    0
# 4                        1                    1                    0
#
#    Festival_Yes  City_Semi-Urban  City_Urban  Time_taken
# 0             0                0           1          24
# 1             0                0           0          33
# 2             0                0           1          26
# 3             0                0           0          21
# 4             0                0           0          30
#
# [5 rows x 23 columns]

# %%
np.random.seed(42)
shuffled_indices = np.random.permutation(len(data))

train_size = int(len(data) * 0.8)

data_train = data.iloc[shuffled_indices[:train_size]]
data_test = data.iloc[shuffled_indices[train_size:]]

# %%
X_train = np.array(data_train.drop(columns="Time_taken"))
y_train = np.array(data_train["Time_taken"])
X_test = np.array(data_test.drop(columns="Time_taken"))
y_test = np.array(data_test["Time_taken"])

# %%
X_train = np.hstack([np.ones((X_train.shape[0], 1)), X_train])
X_test = np.hstack([np.ones((X_test.shape[0], 1)), X_test])

# %%
nesterov = NesterovOptimizer(lr=0.05)

# %%
model = QuantileRegressionV1(optimizer=nesterov)

# %%
model.fit(X_train, y_train, epochs=50000)
# Out:
# Epoch 0/50000, Loss: 23.8476
# Epoch 100/50000, Loss: 1.7104
# Epoch 200/50000, Loss: 1.5882
# Epoch 300/50000, Loss: 1.5191
# Epoch 400/50000, Loss: 1.4715
# Epoch 500/50000, Loss: 1.4363
# Epoch 600/50000, Loss: 1.4092
# Epoch 700/50000, Loss: 1.3876
# Epoch 800/50000, Loss: 1.3698
# Epoch 900/50000, Loss: 1.3544
# Epoch 1000/50000, Loss: 1.3410
# Epoch 1100/50000, Loss: 1.3288
# Epoch 1200/50000, Loss: 1.3177
# Epoch 1300/50000, Loss: 1.3076
# Epoch 1400/50000, Loss: 1.2982
# Epoch 1500/50000, Loss: 1.2895
# Epoch 1600/50000, Loss: 1.2813
# Epoch 1700/50000, Loss: 1.2735
# Epoch 1800/50000, Loss: 1.2661
# Epoch 1900/50000, Loss: 1.2591
# Epoch 2000/50000, Loss: 1.2524
# Epoch 2100/50000, Loss: 1.2460
# Epoch 2200/50000, Loss: 1.2399
# Epoch 2300/50000, Loss: 1.2341
# Epoch 2400/50000, Loss: 1.2285
# Epoch 2500/50000, Loss: 1.2230
# Epoch 2600/50000, Loss: 1.2177
# Epoch 2700/50000, Loss: 1.2126
# Epoch 2800/50000, Loss: 1.2077
# Epoch 2900/50000, Loss: 1.2030
# Epoch 3000/50000, Loss: 1.1985
# Epoch 3100/50000, Loss: 1.1942
# Epoch 3200/50000, Loss: 1.1900
# Epoch 3300/50000, Loss: 1.1859
# Epoch 3400/50000, Loss: 1.1820
# Epoch 3500/50000, Loss: 1.1782
# Epoch 3600/50000, Loss: 1.1746
# Epoch 3700/50000, Loss: 1.1711
# Epoch 3800/50000, Loss: 1.1677
# Epoch 3900/50000, Loss: 1.1644
# Epoch 4000/50000, Loss: 1.1613
# Epoch 4100/50000, Loss: 1.1583
# Epoch 4200/50000, Loss: 1.1554
# Epoch 4300/50000, Loss: 1.1527
# Epoch 4400/50000, Loss: 1.1500
# Epoch 4500/50000, Loss: 1.1475
# Epoch 4600/50000, Loss: 1.1450
# Epoch 4700/50000, Loss: 1.1427
# Epoch 4800/50000, Loss: 1.1404
# Epoch 4900/50000, Loss: 1.1382
# Epoch 5000/50000, Loss: 1.1362
# Epoch 5100/50000, Loss: 1.1342
# Epoch 5200/50000, Loss: 1.1323
# Epoch 5300/50000, Loss: 1.1304
# Epoch 5400/50000, Loss: 1.1286
# Epoch 5500/50000, Loss: 1.1269
# Epoch 5600/50000, Loss: 1.1253
# Epoch 5700/50000, Loss: 1.1237
# Epoch 5800/50000, Loss: 1.1222
# Epoch 5900/50000, Loss: 1.1208
# Epoch 6000/50000, Loss: 1.1194
# Epoch 6100/50000, Loss: 1.1181
# Epoch 6200/50000, Loss: 1.1168
# Epoch 6300/50000, Loss: 1.1156
# Epoch 6400/50000, Loss: 1.1144
# Epoch 6500/50000, Loss: 1.1133
# Epoch 6600/50000, Loss: 1.1123
# Epoch 6700/50000, Loss: 1.1112
# Epoch 6800/50000, Loss: 1.1103
# Epoch 6900/50000, Loss: 1.1094
# Epoch 7000/50000, Loss: 1.1085
# Epoch 7100/50000, Loss: 1.1076
# Epoch 7200/50000, Loss: 1.1068
# Epoch 7300/50000, Loss: 1.1061
# Epoch 7400/50000, Loss: 1.1053
# Epoch 7500/50000, Loss: 1.1047
# Epoch 7600/50000, Loss: 1.1040
# Epoch 7700/50000, Loss: 1.1034
# Epoch 7800/50000, Loss: 1.1028
# Epoch 7900/50000, Loss: 1.1022
# Epoch 8000/50000, Loss: 1.1017
# Epoch 8100/50000, Loss: 1.1011
# Epoch 8200/50000, Loss: 1.1006
# Epoch 8300/50000, Loss: 1.1002
# Epoch 8400/50000, Loss: 1.0997
# Epoch 8500/50000, Loss: 1.0993
# Epoch 8600/50000, Loss: 1.0988
# Epoch 8700/50000, Loss: 1.0984
# Epoch 8800/50000, Loss: 1.0980
# Epoch 8900/50000, Loss: 1.0976
# Epoch 9000/50000, Loss: 1.0973
# Epoch 9100/50000, Loss: 1.0969
# Epoch 9200/50000, Loss: 1.0966
# Epoch 9300/50000, Loss: 1.0963
# Epoch 9400/50000, Loss: 1.0960
# Epoch 9500/50000, Loss: 1.0957
# Epoch 9600/50000, Loss: 1.0954
# Epoch 9700/50000, Loss: 1.0952
# Epoch 9800/50000, Loss: 1.0949
# Epoch 9900/50000, Loss: 1.0947
# Epoch 10000/50000, Loss: 1.0945
# Epoch 10100/50000, Loss: 1.0942
# Epoch 10200/50000, Loss: 1.0940
# Epoch 10300/50000, Loss: 1.0938
# Epoch 10400/50000, Loss: 1.0936
# Epoch 10500/50000, Loss: 1.0935
# Epoch 10600/50000, Loss: 1.0933
# Epoch 10700/50000, Loss: 1.0931
# Epoch 10800/50000, Loss: 1.0929
# Epoch 10900/50000, Loss: 1.0928
# Epoch 11000/50000, Loss: 1.0926
# Epoch 11100/50000, Loss: 1.0925
# Epoch 11200/50000, Loss: 1.0923
# Epoch 11300/50000, Loss: 1.0922
# Epoch 11400/50000, Loss: 1.0921
# Epoch 11500/50000, Loss: 1.0919
# Epoch 11600/50000, Loss: 1.0918
# Epoch 11700/50000, Loss: 1.0917
# Epoch 11800/50000, Loss: 1.0916
# Epoch 11900/50000, Loss: 1.0915
# Epoch 12000/50000, Loss: 1.0914
# Epoch 12100/50000, Loss: 1.0913
# Epoch 12200/50000, Loss: 1.0912
# Epoch 12300/50000, Loss: 1.0911
# Epoch 12400/50000, Loss: 1.0910
# Epoch 12500/50000, Loss: 1.0909
# Epoch 12600/50000, Loss: 1.0908
# Epoch 12700/50000, Loss: 1.0908
# Epoch 12800/50000, Loss: 1.0907
# Epoch 12900/50000, Loss: 1.0906
# Epoch 13000/50000, Loss: 1.0905
# Epoch 13100/50000, Loss: 1.0905
# Epoch 13200/50000, Loss: 1.0904
# Epoch 13300/50000, Loss: 1.0904
# Epoch 13400/50000, Loss: 1.0903
# Epoch 13500/50000, Loss: 1.0902
# Epoch 13600/50000, Loss: 1.0902
# Epoch 13700/50000, Loss: 1.0901
# Epoch 13800/50000, Loss: 1.0901
# Epoch 13900/50000, Loss: 1.0900
# Epoch 14000/50000, Loss: 1.0900
# Epoch 14100/50000, Loss: 1.0900
# Epoch 14200/50000, Loss: 1.0899
# Epoch 14300/50000, Loss: 1.0899
# Epoch 14400/50000, Loss: 1.0898
# Epoch 14500/50000, Loss: 1.0898
# Epoch 14600/50000, Loss: 1.0898
# Epoch 14700/50000, Loss: 1.0897
# Epoch 14800/50000, Loss: 1.0897
# Epoch 14900/50000, Loss: 1.0897
# Epoch 15000/50000, Loss: 1.0896
# Epoch 15100/50000, Loss: 1.0896
# Epoch 15200/50000, Loss: 1.0896
# Epoch 15300/50000, Loss: 1.0896
# Epoch 15400/50000, Loss: 1.0895
# Epoch 15500/50000, Loss: 1.0895
# Epoch 15600/50000, Loss: 1.0895
# Epoch 15700/50000, Loss: 1.0895
# Epoch 15800/50000, Loss: 1.0894
# Epoch 15900/50000, Loss: 1.0894
# Epoch 16000/50000, Loss: 1.0894
# Epoch 16100/50000, Loss: 1.0894
# Epoch 16200/50000, Loss: 1.0893
# Epoch 16300/50000, Loss: 1.0893
# Epoch 16400/50000, Loss: 1.0893
# Epoch 16500/50000, Loss: 1.0893
# Epoch 16600/50000, Loss: 1.0893
# Epoch 16700/50000, Loss: 1.0892
# Epoch 16800/50000, Loss: 1.0892
# Epoch 16900/50000, Loss: 1.0892
# Epoch 17000/50000, Loss: 1.0892
# Epoch 17100/50000, Loss: 1.0892
# Epoch 17200/50000, Loss: 1.0892
# Epoch 17300/50000, Loss: 1.0891
# Epoch 17400/50000, Loss: 1.0891
# Epoch 17500/50000, Loss: 1.0891
# Epoch 17600/50000, Loss: 1.0891
# Epoch 17700/50000, Loss: 1.0891
# Epoch 17800/50000, Loss: 1.0891
# Epoch 17900/50000, Loss: 1.0891
# Epoch 18000/50000, Loss: 1.0891
# Epoch 18100/50000, Loss: 1.0890
# Epoch 18200/50000, Loss: 1.0890
# Epoch 18300/50000, Loss: 1.0890
# Epoch 18400/50000, Loss: 1.0890
# Epoch 18500/50000, Loss: 1.0890
# Epoch 18600/50000, Loss: 1.0890
# Epoch 18700/50000, Loss: 1.0890
# Epoch 18800/50000, Loss: 1.0890
# Epoch 18900/50000, Loss: 1.0890
# Epoch 19000/50000, Loss: 1.0890
# Epoch 19100/50000, Loss: 1.0889
# Epoch 19200/50000, Loss: 1.0889
# Epoch 19300/50000, Loss: 1.0889
# Epoch 19400/50000, Loss: 1.0889
# Epoch 19500/50000, Loss: 1.0889
# Epoch 19600/50000, Loss: 1.0889
# Epoch 19700/50000, Loss: 1.0889
# Epoch 19800/50000, Loss: 1.0889
# Epoch 19900/50000, Loss: 1.0889
# Epoch 20000/50000, Loss: 1.0889
# Epoch 20100/50000, Loss: 1.0889
# Epoch 20200/50000, Loss: 1.0889
# Epoch 20300/50000, Loss: 1.0889
# Epoch 20400/50000, Loss: 1.0889
# Epoch 20500/50000, Loss: 1.0889
# Epoch 20600/50000, Loss: 1.0889
# Epoch 20700/50000, Loss: 1.0889
# Epoch 20800/50000, Loss: 1.0889
# Epoch 20900/50000, Loss: 1.0888
# Epoch 21000/50000, Loss: 1.0888
# Epoch 21100/50000, Loss: 1.0888
# Epoch 21200/50000, Loss: 1.0888
# Epoch 21300/50000, Loss: 1.0888
# Epoch 21400/50000, Loss: 1.0888
# Epoch 21500/50000, Loss: 1.0888
# Epoch 21600/50000, Loss: 1.0888
# Epoch 21700/50000, Loss: 1.0888
# Epoch 21800/50000, Loss: 1.0888
# Epoch 21900/50000, Loss: 1.0888
# Epoch 22000/50000, Loss: 1.0888
# Epoch 22100/50000, Loss: 1.0888
# Epoch 22200/50000, Loss: 1.0888
# Epoch 22300/50000, Loss: 1.0888
# Epoch 22400/50000, Loss: 1.0888
# Epoch 22500/50000, Loss: 1.0888
# Epoch 22600/50000, Loss: 1.0888
# Epoch 22700/50000, Loss: 1.0888
# Epoch 22800/50000, Loss: 1.0888
# Epoch 22900/50000, Loss: 1.0888
# Epoch 23000/50000, Loss: 1.0888
# Epoch 23100/50000, Loss: 1.0888
# Epoch 23200/50000, Loss: 1.0888
# Epoch 23300/50000, Loss: 1.0888
# Epoch 23400/50000, Loss: 1.0888
# Epoch 23500/50000, Loss: 1.0888
# Epoch 23600/50000, Loss: 1.0888
# Epoch 23700/50000, Loss: 1.0888
# Epoch 23800/50000, Loss: 1.0888
# Epoch 23900/50000, Loss: 1.0888
# Epoch 24000/50000, Loss: 1.0888
# Epoch 24100/50000, Loss: 1.0888
# Epoch 24200/50000, Loss: 1.0888
# Epoch 24300/50000, Loss: 1.0888
# Epoch 24400/50000, Loss: 1.0888
# Epoch 24500/50000, Loss: 1.0888
# Epoch 24600/50000, Loss: 1.0888
# Epoch 24700/50000, Loss: 1.0888
# Epoch 24800/50000, Loss: 1.0888
# Epoch 24900/50000, Loss: 1.0888
# Epoch 25000/50000, Loss: 1.0888
# Epoch 25100/50000, Loss: 1.0888
# Epoch 25200/50000, Loss: 1.0888
# Epoch 25300/50000, Loss: 1.0888
# Epoch 25400/50000, Loss: 1.0888
# Epoch 25500/50000, Loss: 1.0888
# Epoch 25600/50000, Loss: 1.0888
# Epoch 25700/50000, Loss: 1.0888
# Epoch 25800/50000, Loss: 1.0888
# Epoch 25900/50000, Loss: 1.0888
# Epoch 26000/50000, Loss: 1.0888
# Epoch 26100/50000, Loss: 1.0888
# Epoch 26200/50000, Loss: 1.0888
# Epoch 26300/50000, Loss: 1.0888
# Epoch 26400/50000, Loss: 1.0888
# Epoch 26500/50000, Loss: 1.0888
# Epoch 26600/50000, Loss: 1.0888
# Epoch 26700/50000, Loss: 1.0888
# Epoch 26800/50000, Loss: 1.0887
# Epoch 26900/50000, Loss: 1.0887
# Epoch 27000/50000, Loss: 1.0887
# Epoch 27100/50000, Loss: 1.0887
# Epoch 27200/50000, Loss: 1.0887
# Epoch 27300/50000, Loss: 1.0887
# Epoch 27400/50000, Loss: 1.0887
# Epoch 27500/50000, Loss: 1.0887
# Epoch 27600/50000, Loss: 1.0887
# Epoch 27700/50000, Loss: 1.0887
# Epoch 27800/50000, Loss: 1.0887
# Epoch 27900/50000, Loss: 1.0887
# Epoch 28000/50000, Loss: 1.0887
# Epoch 28100/50000, Loss: 1.0887
# Epoch 28200/50000, Loss: 1.0887
# Epoch 28300/50000, Loss: 1.0887
# Epoch 28400/50000, Loss: 1.0887
# Epoch 28500/50000, Loss: 1.0887
# Epoch 28600/50000, Loss: 1.0887
# Epoch 28700/50000, Loss: 1.0887
# Epoch 28800/50000, Loss: 1.0887
# Epoch 28900/50000, Loss: 1.0887
# Epoch 29000/50000, Loss: 1.0887
# Epoch 29100/50000, Loss: 1.0887
# Epoch 29200/50000, Loss: 1.0887
# Epoch 29300/50000, Loss: 1.0887
# Epoch 29400/50000, Loss: 1.0887
# Epoch 29500/50000, Loss: 1.0887
# Epoch 29600/50000, Loss: 1.0887
# Epoch 29700/50000, Loss: 1.0887
# Epoch 29800/50000, Loss: 1.0887
# Epoch 29900/50000, Loss: 1.0887
# Epoch 30000/50000, Loss: 1.0887
# Epoch 30100/50000, Loss: 1.0887
# Epoch 30200/50000, Loss: 1.0887
# Epoch 30300/50000, Loss: 1.0887
# Epoch 30400/50000, Loss: 1.0887
# Epoch 30500/50000, Loss: 1.0887
# Epoch 30600/50000, Loss: 1.0887
# Epoch 30700/50000, Loss: 1.0887
# Epoch 30800/50000, Loss: 1.0887
# Epoch 30900/50000, Loss: 1.0887
# Epoch 31000/50000, Loss: 1.0887
# Epoch 31100/50000, Loss: 1.0887
# Epoch 31200/50000, Loss: 1.0887
# Epoch 31300/50000, Loss: 1.0887
# Epoch 31400/50000, Loss: 1.0887
# Epoch 31500/50000, Loss: 1.0887
# Epoch 31600/50000, Loss: 1.0887
# Epoch 31700/50000, Loss: 1.0887
# Epoch 31800/50000, Loss: 1.0887
# Epoch 31900/50000, Loss: 1.0887
# Epoch 32000/50000, Loss: 1.0887
# Epoch 32100/50000, Loss: 1.0887
# Epoch 32200/50000, Loss: 1.0887
# Epoch 32300/50000, Loss: 1.0887
# Epoch 32400/50000, Loss: 1.0887
# Epoch 32500/50000, Loss: 1.0887
# Epoch 32600/50000, Loss: 1.0887
# Epoch 32700/50000, Loss: 1.0887
# Epoch 32800/50000, Loss: 1.0887
# Epoch 32900/50000, Loss: 1.0887
# Epoch 33000/50000, Loss: 1.0887
# Epoch 33100/50000, Loss: 1.0887
# Epoch 33200/50000, Loss: 1.0887
# Epoch 33300/50000, Loss: 1.0887
# Epoch 33400/50000, Loss: 1.0887
# Epoch 33500/50000, Loss: 1.0887
# Epoch 33600/50000, Loss: 1.0887
# Epoch 33700/50000, Loss: 1.0887
# Epoch 33800/50000, Loss: 1.0887
# Epoch 33900/50000, Loss: 1.0887
# Epoch 34000/50000, Loss: 1.0887
# Epoch 34100/50000, Loss: 1.0887
# Epoch 34200/50000, Loss: 1.0887
# Epoch 34300/50000, Loss: 1.0887
# Epoch 34400/50000, Loss: 1.0887
# Epoch 34500/50000, Loss: 1.0887
# Epoch 34600/50000, Loss: 1.0887
# Epoch 34700/50000, Loss: 1.0887
# Epoch 34800/50000, Loss: 1.0887
# Epoch 34900/50000, Loss: 1.0887
# Epoch 35000/50000, Loss: 1.0887
# Epoch 35100/50000, Loss: 1.0887
# Epoch 35200/50000, Loss: 1.0887
# Epoch 35300/50000, Loss: 1.0887
# Epoch 35400/50000, Loss: 1.0887
# Epoch 35500/50000, Loss: 1.0887
# Epoch 35600/50000, Loss: 1.0887
# Epoch 35700/50000, Loss: 1.0887
# Epoch 35800/50000, Loss: 1.0887
# Epoch 35900/50000, Loss: 1.0887
# Epoch 36000/50000, Loss: 1.0887
# Epoch 36100/50000, Loss: 1.0887
# Epoch 36200/50000, Loss: 1.0887
# Epoch 36300/50000, Loss: 1.0887
# Epoch 36400/50000, Loss: 1.0887
# Epoch 36500/50000, Loss: 1.0887
# Epoch 36600/50000, Loss: 1.0887
# Epoch 36700/50000, Loss: 1.0887
# Epoch 36800/50000, Loss: 1.0887
# Epoch 36900/50000, Loss: 1.0887
# Epoch 37000/50000, Loss: 1.0887
# Epoch 37100/50000, Loss: 1.0887
# Epoch 37200/50000, Loss: 1.0887
# Epoch 37300/50000, Loss: 1.0887
# Epoch 37400/50000, Loss: 1.0887
# Epoch 37500/50000, Loss: 1.0887
# Epoch 37600/50000, Loss: 1.0887
# Epoch 37700/50000, Loss: 1.0887
# Epoch 37800/50000, Loss: 1.0887
# Epoch 37900/50000, Loss: 1.0887
# Epoch 38000/50000, Loss: 1.0887
# Epoch 38100/50000, Loss: 1.0887
# Epoch 38200/50000, Loss: 1.0887
# Epoch 38300/50000, Loss: 1.0887
# Epoch 38400/50000, Loss: 1.0887
# Epoch 38500/50000, Loss: 1.0887
# Epoch 38600/50000, Loss: 1.0887
# Epoch 38700/50000, Loss: 1.0887
# Epoch 38800/50000, Loss: 1.0887
# Epoch 38900/50000, Loss: 1.0887
# Epoch 39000/50000, Loss: 1.0887
# Epoch 39100/50000, Loss: 1.0887
# Epoch 39200/50000, Loss: 1.0887
# Epoch 39300/50000, Loss: 1.0887
# Epoch 39400/50000, Loss: 1.0887
# Epoch 39500/50000, Loss: 1.0887
# Epoch 39600/50000, Loss: 1.0887
# Epoch 39700/50000, Loss: 1.0887
# Epoch 39800/50000, Loss: 1.0887
# Epoch 39900/50000, Loss: 1.0887
# Epoch 40000/50000, Loss: 1.0887
# Epoch 40100/50000, Loss: 1.0887
# Epoch 40200/50000, Loss: 1.0887
# Epoch 40300/50000, Loss: 1.0887
# Epoch 40400/50000, Loss: 1.0887
# Epoch 40500/50000, Loss: 1.0887
# Epoch 40600/50000, Loss: 1.0887
# Epoch 40700/50000, Loss: 1.0887
# Epoch 40800/50000, Loss: 1.0887
# Epoch 40900/50000, Loss: 1.0887
# Epoch 41000/50000, Loss: 1.0887
# Epoch 41100/50000, Loss: 1.0887
# Epoch 41200/50000, Loss: 1.0887
# Epoch 41300/50000, Loss: 1.0887
# Epoch 41400/50000, Loss: 1.0887
# Epoch 41500/50000, Loss: 1.0887
# Epoch 41600/50000, Loss: 1.0887
# Epoch 41700/50000, Loss: 1.0887
# Epoch 41800/50000, Loss: 1.0887
# Epoch 41900/50000, Loss: 1.0887
# Epoch 42000/50000, Loss: 1.0887
# Epoch 42100/50000, Loss: 1.0887
# Epoch 42200/50000, Loss: 1.0887
# Epoch 42300/50000, Loss: 1.0887
# Epoch 42400/50000, Loss: 1.0887
# Epoch 42500/50000, Loss: 1.0887
# Epoch 42600/50000, Loss: 1.0887
# Epoch 42700/50000, Loss: 1.0887
# Epoch 42800/50000, Loss: 1.0887
# Epoch 42900/50000, Loss: 1.0887
# Epoch 43000/50000, Loss: 1.0887
# Epoch 43100/50000, Loss: 1.0887
# Epoch 43200/50000, Loss: 1.0887
# Epoch 43300/50000, Loss: 1.0887
# Epoch 43400/50000, Loss: 1.0887
# Epoch 43500/50000, Loss: 1.0887
# Epoch 43600/50000, Loss: 1.0887
# Epoch 43700/50000, Loss: 1.0887
# Epoch 43800/50000, Loss: 1.0887
# Epoch 43900/50000, Loss: 1.0887
# Epoch 44000/50000, Loss: 1.0887
# Epoch 44100/50000, Loss: 1.0887
# Epoch 44200/50000, Loss: 1.0887
# Epoch 44300/50000, Loss: 1.0887
# Epoch 44400/50000, Loss: 1.0887
# Epoch 44500/50000, Loss: 1.0887
# Epoch 44600/50000, Loss: 1.0887
# Epoch 44700/50000, Loss: 1.0887
# Epoch 44800/50000, Loss: 1.0887
# Epoch 44900/50000, Loss: 1.0887
# Epoch 45000/50000, Loss: 1.0887
# Epoch 45100/50000, Loss: 1.0887
# Epoch 45200/50000, Loss: 1.0887
# Epoch 45300/50000, Loss: 1.0887
# Epoch 45400/50000, Loss: 1.0887
# Epoch 45500/50000, Loss: 1.0887
# Epoch 45600/50000, Loss: 1.0887
# Epoch 45700/50000, Loss: 1.0887
# Epoch 45800/50000, Loss: 1.0887
# Epoch 45900/50000, Loss: 1.0887
# Epoch 46000/50000, Loss: 1.0887
# Epoch 46100/50000, Loss: 1.0887
# Epoch 46200/50000, Loss: 1.0887
# Epoch 46300/50000, Loss: 1.0887
# Epoch 46400/50000, Loss: 1.0887
# Epoch 46500/50000, Loss: 1.0887
# Epoch 46600/50000, Loss: 1.0887
# Epoch 46700/50000, Loss: 1.0887
# Epoch 46800/50000, Loss: 1.0887
# Epoch 46900/50000, Loss: 1.0887
# Epoch 47000/50000, Loss: 1.0887
# Epoch 47100/50000, Loss: 1.0887
# Epoch 47200/50000, Loss: 1.0887
# Epoch 47300/50000, Loss: 1.0887
# Epoch 47400/50000, Loss: 1.0887
# Epoch 47500/50000, Loss: 1.0887
# Epoch 47600/50000, Loss: 1.0887
# Epoch 47700/50000, Loss: 1.0887
# Epoch 47800/50000, Loss: 1.0887
# Epoch 47900/50000, Loss: 1.0887
# Epoch 48000/50000, Loss: 1.0887
# Epoch 48100/50000, Loss: 1.0887
# Epoch 48200/50000, Loss: 1.0887
# Epoch 48300/50000, Loss: 1.0887
# Epoch 48400/50000, Loss: 1.0887
# Epoch 48500/50000, Loss: 1.0887
# Epoch 48600/50000, Loss: 1.0887
# Epoch 48700/50000, Loss: 1.0887
# Epoch 48800/50000, Loss: 1.0887
# Epoch 48900/50000, Loss: 1.0887
# Epoch 49000/50000, Loss: 1.0887
# Epoch 49100/50000, Loss: 1.0887
# Epoch 49200/50000, Loss: 1.0887
# Epoch 49300/50000, Loss: 1.0887
# Epoch 49400/50000, Loss: 1.0887
# Epoch 49500/50000, Loss: 1.0887
# Epoch 49600/50000, Loss: 1.0887
# Epoch 49700/50000, Loss: 1.0887
# Epoch 49800/50000, Loss: 1.0887
# Epoch 49900/50000, Loss: 1.0887
# Epoch 49999/50000, Loss: 1.0887

# %%
loss = model.loss

# %%
plt.figure(figsize=(10, 5))
plt.plot(loss, label='Pinball Loss', color='#1E88E5', linewidth=2)

plt.title('Training Loss Curve (Quantile Regression)', fontsize=14, fontweight='bold', pad=15)
plt.xlabel('Epochs', fontsize=12, labelpad=10)
plt.ylabel('Loss Value (lr=0.01)', fontsize=12, labelpad=10)

plt.grid(True, linestyle='--', alpha=0.5)
plt.legend(fontsize=11, loc='upper right')

plt.tight_layout()
plt.show()

# %%
y_pred = model.predict(X_test)

test_pinball_loss = model.pinball_loss(y_test, y_pred)
test_mae = np.mean(np.abs(y_test - y_pred))
test_rmse = np.sqrt(np.mean((y_test - y_pred)**2))

coverage_ratio = np.mean(y_test <= y_pred)

print(f"Test Pinball Loss (tau=0.9): {test_pinball_loss:.4f}")
print(f"Test MAE: {test_mae:.4f}")
print(f"Test RMSE: {test_rmse:.4f}")
print(f"Test Coverage Ratio: {coverage_ratio:.4f}")
# Out:
# Test Pinball Loss (tau=0.9): 1.0786
# Test MAE: 8.5121
# Test RMSE: 10.0992
# Test Coverage Ratio: 0.8960

# %%
model.save_weights("../../results/weights/Nesterov/nesterov_weights.npy")
# Out:
# Saved.

# %%
np.save("../../results/weights/Nesterov/nesterov_loss_1.npy", np.array(loss))
print("Đã lưu biến loss thành công.")
# Out:
# Đã lưu biến loss thành công.

# %%
# 1. Đọc dữ liệu loss từ các tệp .npy
# (Đường dẫn tương đối tính từ thư mục notebooks/training/)
loss_01 = np.load("../../results/weights/Nesterov/nesterov_loss_01.npy")
loss_05 = np.load("../../results/weights/Nesterov/nesterov_loss_05.npy")
loss_1 = np.load("../../results/weights/Nesterov/nesterov_loss_1.npy")

# 2. Khởi tạo biểu đồ so sánh
plt.figure(figsize=(12, 6))

# Vẽ 3 đường với các màu sắc tương phản rõ nét
plt.plot(loss_01[:4000], label='lr = 0.01', color='#E53935', linewidth=1.8, alpha=0.9)
plt.plot(loss_05[:4000], label='lr = 0.05', color='#FFB300', linewidth=1.8, alpha=0.9)
plt.plot(loss_1[:4000], label='lr = 0.1', color='#1E88E5', linewidth=1.8, alpha=0.9)

# Cấu hình tiêu đề và các trục tọa độ
plt.title('Nesterov Optimizer: Đường cong hàm mất mát', fontsize=14, fontweight='bold', pad=15)
plt.xlabel('Epochs', fontsize=12, labelpad=10)
plt.ylabel('Giá trị hàm loss', fontsize=12, labelpad=10)

# Cấu hình lưới bổ trợ (grid) và ghi chú (legend)
plt.grid(True, linestyle='--', alpha=0.5)
plt.legend(fontsize=11, loc='upper right')

# Tối ưu hóa khoảng cách hiển thị
plt.tight_layout()

# Hiển thị đồ thị
plt.show()
